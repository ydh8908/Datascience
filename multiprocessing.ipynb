# %%
import pandas as pd
import datetime as dt
from datetime import timedelta, date
import time
import numpy as np
import pyupbit
import requests
import inflect
from multiprocessing import Pool

p = inflect.engine()
def get_list(ticker):
    vars[ticker]=[]

tickers = pyupbit.get_tickers('KRW')

def p_ticker(ticker):
    for i in range (1000):
        print(i, ticker)



# def get_data(ticker):
#     vars()['df_raw'+ticker]=[]
#     url = "https://api.upbit.com/v1/candles/minutes/1"
#     querystring = {"market": ticker, "to": '2019-12-01 10:00:00', "count": "1"}
#     response = requests.request("GET", url, params=querystring)
#     vars()['df_raw'+ticker+'1'] = response.json()
#     vars()['df_raw'+ticker+'1'] = pd.DataFrame(vars()['df_raw'+ticker+'1'])
#     vars()['df_raw'+ticker].append(vars()['df_raw'+ticker+'1'])
#     print((vars()['df_raw'+ticker]))

pool = Pool(processes=1) # 4개의 프로세스를 사용합니다.
pool.map(p_ticker, tickers)
# Out:
# Exception in thread IPythonHistorySavingThread:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/history.py", line 834, in run
#     self.history_manager.writeout_cache(self.db)
#   File "</opt/anaconda3/lib/python3.7/site-packages/decorator.py:decorator-gen-23>", line 2, in writeout_cache
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/history.py", line 58, in needs_sqlite
#     return f(self, *a, **kw)
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/history.py", line 780, in writeout_cache
#     self._writeout_input_cache(conn)
#   File "/opt/anaconda3/lib/python3.7/site-packages/IPython/core/history.py", line 764, in _writeout_input_cache
#     (self.session_number,)+line)
# sqlite3.OperationalError: unable to open database file
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...
