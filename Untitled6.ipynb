# %%
import pybithumb
import time
import pandas as pd

# tickers = pybithumb.get_tickers()
# for ticker in tickers:
#     price = pybithumb.get_current_price(ticker)
#     print(ticker, price)
#     time.sleep(0.1)

# detail = pybithumb. get_market_detail("BTC")
# print(detail)

# orderbook = pybithumb.get_ohlcv("BTC")
# print(orderbook)

all = pybithumb.get_current_price("All")
df = pd.DataFrame(all).re
df
# Out:
#      status                                               data
# ABT    0000  {'opening_price': '179', 'closing_price': '177...
# ADA    0000  {'opening_price': '46.8', 'closing_price': '45...
# AE     0000  {'opening_price': '233', 'closing_price': '226...
# AMO    0000  {'opening_price': '0.26', 'closing_price': '0....
# ANKR   0000  {'opening_price': '2.26', 'closing_price': '2....
# ...     ...                                                ...
# XVG    0000  {'opening_price': '4.58', 'closing_price': '4....
# ZEC    0000  {'opening_price': '33420', 'closing_price': '3...
# ZIL    0000  {'opening_price': '6.72', 'closing_price': '7....
# ZRX    0000  {'opening_price': '305', 'closing_price': '294...
# date   0000                                      1575184078975
#
# [107 rows x 2 columns]
